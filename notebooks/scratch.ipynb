# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import urllib

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
raw_html = simple_get('https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999/')

# %%
html = BeautifulSoup(raw_html, 'html.parser')

# %%
url_base = "https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999/"
for td in html.select('td'):
    if td.a:
        print(f"{url_base}/{td.a['href']}")
# Out:
# https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999//grant_pdf_17900731_18641101.tar
# https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999//grant_pdf_18641108_18700823.tar
# https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999//grant_pdf_18700830_18750209.tar
# https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999//grant_pdf_18750216_18790318.tar
# https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999//grant_pdf_18790325_18820613.tar
# https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999//grant_pdf_18820620_18840624.tar
# https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999//grant_pdf_18840701_18860511.tar
# https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999//grant_pdf_18860518_18880410.tar
# https://bulkdata.uspto.gov/data/patent/grant/multipagepdf/1790_1999//grant_pdf_18880417_18891217.tar
# ...

# %%
url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-5446fb31b66c> in <module>
# ----> 1 url
#
# NameError: name 'url' is not defined

# %%
from urllib import url
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-ae43dc43c4ea> in <module>
# ----> 1 from urllib import url
#
# ImportError: cannot import name 'url' from 'urllib' (/Users/willthompson/anaconda3/envs/patent-data/lib/python3.7/urllib/__init__.py)
